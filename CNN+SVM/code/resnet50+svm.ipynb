# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from PIL import Image
import torch
from torch import nn
import torch.optim as optim
import torchvision
from torchvision import transforms, models, datasets
#https://pytorch.org/docs/stable/torchvision/index.html
# import imageio
import time
import warnings
import random
import sys
import copy
import json

# %% [markdown]
# ### 1. 数据读取与预处理操作

# %%
data_dir = '../face_data/sex/'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %% [markdown]
# #### 制作好数据源:
# - data_transforms中指定了所有图像预处理操作
# - lmageFolder假设所有的文件按文件夹保存好，每个文件夹下面存贮同一类别的图片，文件夹的名字为分类的名字
# - 因为上采样数据集为（256，256），所以在这里做了中心裁剪到（224，224）
# - 因为上采样数据集样本量较小，故在这里做了数据增强，有：1、随机旋转，-45到45度之间随机旋转；2、随机水平翻转；3、随机垂直翻转；4、随机亮度、对比度、饱和度、色相

# %%
# 一通道
data_transforms = {
    'train': transforms.Compose([transforms.Grayscale(1), # 将图像转换为单通道图像
        transforms.RandomRotation(45), #随机旋转，-45到45度之间随机旋转
        transforms.CenterCrop(224), # 从中心开始裁剪
        transforms.RandomHorizontalFlip(p=0.5), # 随机水平翻转 选择一个概率概率
        transforms.RandomVerticalFlip(p=0.5),   # 随机垂直翻转
        transforms.ColorJitter(brightness=0.2, contrast=0.1, saturation=0.1, hue=0.1),# 亮度、对比度、饱和度、色相
        transforms.ToTensor(),
        transforms.Normalize(0.485, 0.229)#均值，标准差 单通道只需一个值
    ]),
    'valid': transforms.Compose([transforms.Grayscale(1),
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(0.485, 0.229)
    ]),
}

# %%
batch_size = 16

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'valid' ]}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True) for x in ['train', 'valid']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'valid']}
class_names = image_datasets['train'].classes

# %%
print(image_datasets)
print(dataloaders)
print(dataset_sizes)
print(class_names)
# Out:
# {'train': Dataset ImageFolder
#     Number of datapoints: 3422
#     Root location: ../face_data/sex/train
#     StandardTransform
# Transform: Compose(
#                Grayscale(num_output_channels=1)
#                RandomRotation(degrees=[-45.0, 45.0], interpolation=nearest, expand=False, fill=0)
#                CenterCrop(size=(224, 224))
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.5)
#                ColorJitter(brightness=[0.8, 1.2], contrast=[0.9, 1.1], saturation=[0.9, 1.1], hue=[-0.1, 0.1])
#                ToTensor()
#                Normalize(mean=0.485, std=0.229)
#            ), 'valid': Dataset ImageFolder
#     Number of datapoints: 396
#     Root location: ../face_data/sex/valid
#     StandardTransform
# Transform: Compose(
#                Grayscale(num_output_channels=1)
#                Resize(size=256, interpolation=bilinear)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=0.485, std=0.229)
#            )}
# {'train': <torch.utils.data.dataloader.DataLoader object at 0x7fcc47269a10>, 'valid': <torch.utils.data.dataloader.DataLoader object at 0x7fcc47398e50>}
# {'train': 3422, 'valid': 396}
# ['female', 'male']

# %% [markdown]
# ### 2. 加载Resnet模型进行迁移学习
# - 直接用训练的好权重当做初始化参数

# %%
#是否用GPU训练
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu :
    print('CUDA is not available. Training on CPU ...')
else:
    print('CUDA is available! Training on GPU ...')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False
            
            
# 初始化model，修改resnet为自己想要的
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    model_ft = None
    input_size = 0

    if model_name == "resnet" :
        model_ft = models.resnet50(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract) # 设置参数使用预训练模型
        model_ft.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False) # 灰度图通道为1
        num_ftrs = model_ft.fc.in_features # 得到resnet最后一层的输入为2048
        # model_ft.fc = nn.Sequential(nn.Linear(num_ftrs, 512), nn.Linear(512, num_classes), nn.LogSoftmax (dim=1))
        model_ft.fc = nn.Sequential(nn.Linear(num_ftrs, 100), nn.Linear(100, num_classes), nn.LogSoftmax (dim=1))
        
        input_size = 224
    return model_ft, input_size
# Out:
# CUDA is available! Training on GPU ...

# %% [markdown]
# #### 需要训练哪些层

# %%
model_name = 'resnet'
feature_extract = True # 是否用人家训练好的特征来做

model_ft, input_size = initialize_model(model_name, 2, feature_extract, use_pretrained=True)

#GPU计算
model_ft = model_ft.to(device)

#模型保存
filename = '../modle_save/checkpoint.pth'

#是否训练所有层
params_to_update = model_ft.parameters()
print ("Params to learn:")
if feature_extract:
    params_to_update = []
    for name, param in model_ft.named_parameters() :
        if param.requires_grad == True:
            params_to_update.append (param)
            print(" \t" , name)
else:
    for name, param in model_ft.named_parameters() :
        if param.requires_grad == True:
            print(" \t" , name)
# Out:
# Params to learn:
#  	 conv1.weight
#  	 fc.0.weight
#  	 fc.0.bias
#  	 fc.1.weight
#  	 fc.1.bias

# %% [markdown]
# ### 优化器设置

# %%
#优化器设置
optimizer_ft = optim.Adam (params_to_update, lr=1e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)#学习率每7个epoch衰减成原来的1/10
#最后一层已经LogSoftmax()了，所以不能nn. brossEntropyloss()来计算了，n.CrossEntropyloss()相当于logSoftmax()和nn.NLLoss()整合
criterion = nn.NLLLoss()

# %% [markdown]
# ### 训练模块

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, filename=filename):
    since = time.time()
    best_acc = 0

    model.to(device)
    val_acc_history = []
    train_acc_history = []
    train_losses = []
    valid_losses = []
    LRs = [optimizer.param_groups[0]['lr']]
    
    best_model_wts = copy.deepcopy(model.state_dict())
                                   
    for epoch in range (num_epochs) :
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
    
        #训练和验证
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train() # 训练
            else:
                model.eval()  # 验证

            running_loss = 0.0
            running_corrects = 0

            #把数据都取个遍
            for inputs, labels in dataloaders[phase] :
                inputs = inputs.to(device)
                labels = labels.to(device)

                #清零
                optimizer.zero_grad()
                #只有训练的时候计算和更新梯度
                with torch.set_grad_enabled(phase == 'train') :
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    #训练阶段更新权重
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                #计算损失
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)


            time_elapsed = time.time() - since
            print('Time elapsed {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
            print('{} Loss: {:.4f} Acc: {:.4f} '.format(phase, epoch_loss, epoch_acc))


            #得到最好那次的模型
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                state = {
                    'state_dict' : model.state_dict(),
                    'best_acc': best_acc,
                    'optimizer' : optimizer.state_dict(),
                }
                torch.save(state, filename)  # 保存最优结果
            if phase == 'valid':
                val_acc_history.append(epoch_acc)
                valid_losses.append (epoch_loss)
                scheduler.step(epoch_loss)
            if phase == 'train':
                train_acc_history.append(epoch_acc)
                train_losses.append(epoch_loss)

        print('Optimizer learning rate : {:.7f}'.format(optimizer.param_groups[0]['lr']))
        LRs.append(optimizer.param_groups[0]['lr'])
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f} s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {: 4f} '.format(best_acc))
    
    #训练完后用最好的一次当做模型最终的结果
    model.load_state_dict(best_model_wts) # 读取最优结果
    return model, val_acc_history, train_acc_history, valid_losses, train_losses, LRs

# %% [markdown]
# ### 二次训练
# - 第一次训练第一个卷积核和最后两层全连接层参数
# - 第二次训练所有参数（使用第一次训练的最优模型）

# %%
# 初始训练
model_name = 'resnet'
feature_extract = True # 是否用人家训练好的特征来做

model_ft, input_size = initialize_model(model_name, 2, feature_extract, use_pretrained=True)

#GPU计算
model_ft = model_ft.to(device)

#是否训练所有层
params_to_update = model_ft.parameters()
print ("Params to learn:")
if feature_extract:
    params_to_update = []
    for name, param in model_ft.named_parameters() :
        if param.requires_grad == True:
            params_to_update.append (param)
            print(" \t" , name)
else:
    for name, param in model_ft.named_parameters() :
        if param.requires_grad == True:
            print(" \t" , name)
#优化器设置
optimizer_ft = optim.Adam (params_to_update, lr=1e-4)
criterion = nn.NLLLoss()

filename = '../modle_save/checkpoint.pth'
epochs = 56
model_ft, val_ace_history, train_acc_history, valid_losses, train_losses, LRs = train_model(model_ft, dataloaders, criterion, optimizer_ft, filename=filename, num_epochs=epochs)
# 保存整个模型
checkpoint = torch.load(filename)
model_ft.load_state_dict(checkpoint['state_dict'])
torch.save(model_ft, '../modle_save/modle_all.pth')



# 再继续训练所有的参数，学习率调小一点
best_acc = checkpoint['best_acc']
print(best_acc)

params_to_update = model_ft.parameters()
optimizer = optim.Adam(params_to_update, lr=1e-5)
criterion = nn.NLLLoss()

# 再次训练
filename = '../modle_save/checkpoint_again.pth'
epochs = 56
model_ft, val_ace_history, train_acc_history, valid_losses, train_losses, LRs = train_model(model_ft, dataloaders, criterion, optimizer, filename=filename, num_epochs=epochs)
# 保存整个模型
checkpoint = torch.load(filename)
model_ft.load_state_dict(checkpoint['state_dict'])
torch.save(model_ft, '../modle_save/modle_all_again.pth')
# Out:
# Params to learn:
#  	 conv1.weight
#  	 fc.0.weight
#  	 fc.0.bias
#  	 fc.1.weight
#  	 fc.1.bias
# Epoch 0/55
# ----------
# Time elapsed 0m 15s
# train Loss: 0.6642 Acc: 0.6052
# Time elapsed 0m 15s
# valid Loss: 0.6288 Acc: 0.6389
# Optimizer learning rate : 0.0001000
#
# Epoch 1/55
# ----------
# Time elapsed 0m 30s
# train Loss: 0.6445 Acc: 0.6306
# Time elapsed 0m 31s
# valid Loss: 0.6088 Acc: 0.6818
# Optimizer learning rate : 0.0001000
#
# Epoch 2/55
# ----------
# Time elapsed 0m 46s
# train Loss: 0.6389 Acc: 0.6409
# Time elapsed 0m 47s
# valid Loss: 0.5975 Acc: 0.6742
# Optimizer learning rate : 0.0001000
#
# Epoch 3/55
# ----------
# Time elapsed 1m 2s
# train Loss: 0.6343 Acc: 0.6470
# Time elapsed 1m 2s
# valid Loss: 0.6036 Acc: 0.6970
# Optimizer learning rate : 0.0001000
#
# Epoch 4/55
# ----------
# Time elapsed 1m 17s
# train Loss: 0.6219 Acc: 0.6493
# Time elapsed 1m 18s
# valid Loss: 0.7366 Acc: 0.5404
# Optimizer learning rate : 0.0001000
#
# Epoch 5/55
# ----------
# Time elapsed 1m 33s
# train Loss: 0.6096 Acc: 0.6704
# Time elapsed 1m 34s
# valid Loss: 0.5838 Acc: 0.6793
# Optimizer learning rate : 0.0001000
#
# Epoch 6/55
# ----------
# Time elapsed 1m 49s
# train Loss: 0.5984 Acc: 0.6753
# Time elapsed 1m 49s
# valid Loss: 0.5972 Acc: 0.6742
# Optimizer learning rate : 0.0001000
#
# Epoch 7/55
# ----------
# Time elapsed 2m 4s
# train Loss: 0.6103 Acc: 0.6689
# Time elapsed 2m 5s
# valid Loss: 0.5900 Acc: 0.7045
# Optimizer learning rate : 0.0001000
#
# Epoch 8/55
# ----------
# Time elapsed 2m 20s
# train Loss: 0.5880 Acc: 0.6850
# Time elapsed 2m 20s
# valid Loss: 0.5886 Acc: 0.7045
# Optimizer learning rate : 0.0001000
#
# Epoch 9/55
# ----------
# Time elapsed 2m 35s
# train Loss: 0.5839 Acc: 0.6905
# Time elapsed 2m 36s
# valid Loss: 0.5763 Acc: 0.7399
# Optimizer learning rate : 0.0001000
#
# Epoch 10/55
# ----------
# Time elapsed 2m 51s
# train Loss: 0.5934 Acc: 0.6771
# Time elapsed 2m 52s
# valid Loss: 0.5777 Acc: 0.7348
# Optimizer learning rate : 0.0001000
#
# Epoch 11/55
# ----------
# Time elapsed 3m 6s
# train Loss: 0.6002 Acc: 0.6733
# Time elapsed 3m 7s
# valid Loss: 0.5660 Acc: 0.7374
# Optimizer learning rate : 0.0001000
#
# Epoch 12/55
# ----------
# Time elapsed 3m 22s
# train Loss: 0.5848 Acc: 0.6897
# Time elapsed 3m 22s
# valid Loss: 0.5778 Acc: 0.6490
# Optimizer learning rate : 0.0001000
#
# Epoch 13/55
# ----------
# Time elapsed 3m 37s
# train Loss: 0.5838 Acc: 0.6911
# Time elapsed 3m 38s
# valid Loss: 0.5537 Acc: 0.7121
# Optimizer learning rate : 0.0001000
#
# Epoch 14/55
# ----------
# Time elapsed 3m 52s
# train Loss: 0.5736 Acc: 0.6961
# Time elapsed 3m 53s
# valid Loss: 0.5730 Acc: 0.6793
# Optimizer learning rate : 0.0001000
#
# Epoch 15/55
# ----------
# Time elapsed 4m 8s
# train Loss: 0.5690 Acc: 0.7046
# Time elapsed 4m 9s
# valid Loss: 0.5627 Acc: 0.7121
# Optimizer learning rate : 0.0001000
#
# Epoch 16/55
# ----------
# Time elapsed 4m 23s
# train Loss: 0.5686 Acc: 0.6999
# Time elapsed 4m 24s
# valid Loss: 0.6184 Acc: 0.6894
# Optimizer learning rate : 0.0001000
#
# Epoch 17/55
# ----------
# Time elapsed 4m 39s
# train Loss: 0.5607 Acc: 0.7098
# Time elapsed 4m 39s
# valid Loss: 0.5946 Acc: 0.7071
# Optimizer learning rate : 0.0001000
#
# Epoch 18/55
# ----------
# Time elapsed 4m 54s
# train Loss: 0.5749 Acc: 0.6961
# Time elapsed 4m 55s
# valid Loss: 0.5607 Acc: 0.7071
# Optimizer learning rate : 0.0001000
#
# Epoch 19/55
# ----------
# Time elapsed 5m 10s
# train Loss: 0.5747 Acc: 0.7008
# Time elapsed 5m 10s
# valid Loss: 0.5692 Acc: 0.7273
# Optimizer learning rate : 0.0001000
#
# Epoch 20/55
# ----------
# Time elapsed 5m 25s
# train Loss: 0.5818 Acc: 0.6917
# Time elapsed 5m 26s
# valid Loss: 0.5743 Acc: 0.7247
# Optimizer learning rate : 0.0001000
#
# Epoch 21/55
# ----------
# Time elapsed 5m 40s
# train Loss: 0.5625 Acc: 0.7054
# Time elapsed 5m 41s
# valid Loss: 0.5507 Acc: 0.7121
# Optimizer learning rate : 0.0001000
#
# Epoch 22/55
# ----------
# Time elapsed 5m 56s
# train Loss: 0.5587 Acc: 0.7206
# Time elapsed 5m 57s
# valid Loss: 0.5306 Acc: 0.7222
# Optimizer learning rate : 0.0001000
#
# Epoch 23/55
# ----------
# Time elapsed 6m 12s
# train Loss: 0.5549 Acc: 0.7084
# Time elapsed 6m 12s
# valid Loss: 0.5854 Acc: 0.7222
# Optimizer learning rate : 0.0001000
#
# Epoch 24/55
# ----------
# Time elapsed 6m 27s
# train Loss: 0.5606 Acc: 0.7107
# Time elapsed 6m 28s
# valid Loss: 0.5441 Acc: 0.7146
# Optimizer learning rate : 0.0001000
#
# Epoch 25/55
# ----------
# Time elapsed 6m 43s
# train Loss: 0.5649 Acc: 0.6978
# Time elapsed 6m 43s
# valid Loss: 0.5547 Acc: 0.7399
# Optimizer learning rate : 0.0001000
#
# Epoch 26/55
# ----------
# Time elapsed 6m 58s
# train Loss: 0.5654 Acc: 0.7031
# Time elapsed 6m 59s
# valid Loss: 0.5509 Acc: 0.7374
# Optimizer learning rate : 0.0001000
#
# Epoch 27/55
# ----------
# Time elapsed 7m 13s
# train Loss: 0.5584 Acc: 0.7086
# Time elapsed 7m 14s
# valid Loss: 0.5837 Acc: 0.7273
# Optimizer learning rate : 0.0001000
#
# Epoch 28/55
# ----------
# Time elapsed 7m 29s
# train Loss: 0.5700 Acc: 0.7034
# Time elapsed 7m 30s
# valid Loss: 0.5454 Acc: 0.7323
# Optimizer learning rate : 0.0001000
#
# Epoch 29/55
# ----------
# Time elapsed 7m 44s
# train Loss: 0.5583 Acc: 0.7148
# Time elapsed 7m 45s
# valid Loss: 0.5343 Acc: 0.7449
# Optimizer learning rate : 0.0001000
#
# Epoch 30/55
# ----------
# Time elapsed 8m 0s
# train Loss: 0.5607 Acc: 0.7104
# Time elapsed 8m 1s
# valid Loss: 0.6085 Acc: 0.6742
# Optimizer learning rate : 0.0001000
#
# Epoch 31/55
# ----------
# Time elapsed 8m 16s
# train Loss: 0.5655 Acc: 0.7089
# Time elapsed 8m 16s
# valid Loss: 0.5265 Acc: 0.7348
# Optimizer learning rate : 0.0001000
#
# Epoch 32/55
# ----------
# Time elapsed 8m 31s
# train Loss: 0.5422 Acc: 0.7127
# Time elapsed 8m 32s
# valid Loss: 0.5183 Acc: 0.7475
# Optimizer learning rate : 0.0001000
#
# Epoch 33/55
# ----------
# Time elapsed 8m 47s
# train Loss: 0.5727 Acc: 0.6981
# Time elapsed 8m 48s
# valid Loss: 0.5669 Acc: 0.7247
# Optimizer learning rate : 0.0001000
#
# Epoch 34/55
# ----------
# Time elapsed 9m 2s
# train Loss: 0.5631 Acc: 0.7081
# Time elapsed 9m 3s
# valid Loss: 0.5216 Acc: 0.7475
# Optimizer learning rate : 0.0001000
#
# Epoch 35/55
# ----------
# Time elapsed 9m 18s
# train Loss: 0.5558 Acc: 0.7092
# Time elapsed 9m 18s
# valid Loss: 0.5210 Acc: 0.7576
# Optimizer learning rate : 0.0001000
#
# Epoch 36/55
# ----------
# Time elapsed 9m 34s
# train Loss: 0.5500 Acc: 0.7200
# Time elapsed 9m 34s
# valid Loss: 0.5008 Acc: 0.7727
# Optimizer learning rate : 0.0001000
#
# Epoch 37/55
# ----------
# Time elapsed 9m 49s
# train Loss: 0.5489 Acc: 0.7233
# Time elapsed 9m 50s
# valid Loss: 0.5440 Acc: 0.7323
# Optimizer learning rate : 0.0001000
#
# Epoch 38/55
# ----------
# Time elapsed 10m 5s
# train Loss: 0.5391 Acc: 0.7279
# Time elapsed 10m 5s
# valid Loss: 0.5125 Acc: 0.7424
# Optimizer learning rate : 0.0001000
#
# Epoch 39/55
# ----------
# Time elapsed 10m 20s
# train Loss: 0.5324 Acc: 0.7276
# Time elapsed 10m 21s
# valid Loss: 0.5450 Acc: 0.7298
# Optimizer learning rate : 0.0001000
#
# Epoch 40/55
# ----------
# Time elapsed 10m 36s
# train Loss: 0.5571 Acc: 0.7072
# Time elapsed 10m 36s
# valid Loss: 0.5212 Acc: 0.7222
# Optimizer learning rate : 0.0001000
#
# Epoch 41/55
# ----------
# Time elapsed 10m 51s
# train Loss: 0.5565 Acc: 0.7104
# Time elapsed 10m 52s
# valid Loss: 0.5277 Acc: 0.7551
# Optimizer learning rate : 0.0001000
#
# Epoch 42/55
# ----------
# Time elapsed 11m 7s
# train Loss: 0.5457 Acc: 0.7200
# Time elapsed 11m 7s
# valid Loss: 0.5449 Acc: 0.7247
# Optimizer learning rate : 0.0001000
#
# Epoch 43/55
# ----------
# Time elapsed 11m 22s
# train Loss: 0.5484 Acc: 0.7200
# Time elapsed 11m 23s
# valid Loss: 0.4909 Acc: 0.7677
# Optimizer learning rate : 0.0001000
#
# Epoch 44/55
# ----------
# Time elapsed 11m 37s
# train Loss: 0.5353 Acc: 0.7291
# Time elapsed 11m 38s
# valid Loss: 0.5042 Acc: 0.7803
# Optimizer learning rate : 0.0001000
#
# Epoch 45/55
# ----------
# Time elapsed 11m 53s
# train Loss: 0.5545 Acc: 0.7104
# Time elapsed 11m 54s
# valid Loss: 0.5155 Acc: 0.7374
# Optimizer learning rate : 0.0001000
#
# Epoch 46/55
# ----------
# Time elapsed 12m 9s
# train Loss: 0.5466 Acc: 0.7203
# Time elapsed 12m 9s
# valid Loss: 0.5190 Acc: 0.7601
# Optimizer learning rate : 0.0001000
#
# Epoch 47/55
# ----------
# Time elapsed 12m 24s
# train Loss: 0.5389 Acc: 0.7274
# Time elapsed 12m 25s
# valid Loss: 0.5415 Acc: 0.7626
# Optimizer learning rate : 0.0001000
#
# Epoch 48/55
# ----------
# Time elapsed 12m 39s
# train Loss: 0.5487 Acc: 0.7119
# Time elapsed 12m 40s
# valid Loss: 0.5304 Acc: 0.7652
# Optimizer learning rate : 0.0001000
#
# Epoch 49/55
# ----------
# Time elapsed 12m 55s
# train Loss: 0.5337 Acc: 0.7200
# Time elapsed 12m 56s
# valid Loss: 0.5273 Acc: 0.7323
# Optimizer learning rate : 0.0001000
#
# Epoch 50/55
# ----------
# Time elapsed 13m 10s
# train Loss: 0.5269 Acc: 0.7402
# Time elapsed 13m 11s
# valid Loss: 0.5523 Acc: 0.7399
# Optimizer learning rate : 0.0001000
#
# Epoch 51/55
# ----------
# Time elapsed 13m 26s
# train Loss: 0.5299 Acc: 0.7341
# Time elapsed 13m 27s
# valid Loss: 0.5394 Acc: 0.7323
# Optimizer learning rate : 0.0001000
#
# Epoch 52/55
# ----------
# Time elapsed 13m 41s
# train Loss: 0.5277 Acc: 0.7382
# Time elapsed 13m 42s
# valid Loss: 0.4759 Acc: 0.7727
# Optimizer learning rate : 0.0001000
#
# Epoch 53/55
# ----------
# Time elapsed 13m 57s
# train Loss: 0.5289 Acc: 0.7326
# Time elapsed 13m 57s
# valid Loss: 0.4714 Acc: 0.7828
# Optimizer learning rate : 0.0001000
#
# Epoch 54/55
# ----------
# Time elapsed 14m 12s
# train Loss: 0.5341 Acc: 0.7244
# Time elapsed 14m 13s
# valid Loss: 0.4693 Acc: 0.7803
# Optimizer learning rate : 0.0001000
#
# Epoch 55/55
# ----------
# Time elapsed 14m 27s
# train Loss: 0.5374 Acc: 0.7256
# Time elapsed 14m 28s
# valid Loss: 0.5252 Acc: 0.7475
# Optimizer learning rate : 0.0001000
#
# Training complete in 14m 28 s
# Best val Acc:  0.782828
# tensor(0.7828, device='cuda:0', dtype=torch.float64)
# Epoch 0/55
# ----------
# Time elapsed 0m 15s
# train Loss: 0.5222 Acc: 0.7332
# Time elapsed 0m 16s
# valid Loss: 0.4759 Acc: 0.7551
# Optimizer learning rate : 0.0000100
#
# Epoch 1/55
# ----------
# Time elapsed 0m 31s
# train Loss: 0.5202 Acc: 0.7303
# Time elapsed 0m 31s
# valid Loss: 0.4711 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 2/55
# ----------
# Time elapsed 0m 46s
# train Loss: 0.5182 Acc: 0.7347
# Time elapsed 0m 47s
# valid Loss: 0.4627 Acc: 0.7879
# Optimizer learning rate : 0.0000100
#
# Epoch 3/55
# ----------
# Time elapsed 1m 2s
# train Loss: 0.5071 Acc: 0.7446
# Time elapsed 1m 3s
# valid Loss: 0.4706 Acc: 0.7929
# Optimizer learning rate : 0.0000100
#
# Epoch 4/55
# ----------
# Time elapsed 1m 18s
# train Loss: 0.5205 Acc: 0.7405
# Time elapsed 1m 19s
# valid Loss: 0.4632 Acc: 0.7879
# Optimizer learning rate : 0.0000100
#
# Epoch 5/55
# ----------
# Time elapsed 1m 34s
# train Loss: 0.5194 Acc: 0.7405
# Time elapsed 1m 34s
# valid Loss: 0.4668 Acc: 0.7753
# Optimizer learning rate : 0.0000100
#
# Epoch 6/55
# ----------
# Time elapsed 1m 49s
# train Loss: 0.5154 Acc: 0.7379
# Time elapsed 1m 50s
# valid Loss: 0.4688 Acc: 0.7828
# Optimizer learning rate : 0.0000100
#
# Epoch 7/55
# ----------
# Time elapsed 2m 5s
# train Loss: 0.5213 Acc: 0.7379
# Time elapsed 2m 5s
# valid Loss: 0.4737 Acc: 0.7879
# Optimizer learning rate : 0.0000100
#
# Epoch 8/55
# ----------
# Time elapsed 2m 20s
# train Loss: 0.5139 Acc: 0.7428
# Time elapsed 2m 21s
# valid Loss: 0.4715 Acc: 0.7727
# Optimizer learning rate : 0.0000100
#
# Epoch 9/55
# ----------
# Time elapsed 2m 35s
# train Loss: 0.5196 Acc: 0.7361
# Time elapsed 2m 36s
# valid Loss: 0.4711 Acc: 0.7854
# Optimizer learning rate : 0.0000100
#
# Epoch 10/55
# ----------
# Time elapsed 2m 51s
# train Loss: 0.5200 Acc: 0.7332
# Time elapsed 2m 52s
# valid Loss: 0.4686 Acc: 0.7753
# Optimizer learning rate : 0.0000100
#
# Epoch 11/55
# ----------
# Time elapsed 3m 6s
# train Loss: 0.5194 Acc: 0.7399
# Time elapsed 3m 7s
# valid Loss: 0.4688 Acc: 0.7727
# Optimizer learning rate : 0.0000100
#
# Epoch 12/55
# ----------
# Time elapsed 3m 22s
# train Loss: 0.5198 Acc: 0.7411
# Time elapsed 3m 23s
# valid Loss: 0.4762 Acc: 0.7702
# Optimizer learning rate : 0.0000100
#
# Epoch 13/55
# ----------
# Time elapsed 3m 37s
# train Loss: 0.5197 Acc: 0.7455
# Time elapsed 3m 38s
# valid Loss: 0.4649 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 14/55
# ----------
# Time elapsed 3m 53s
# train Loss: 0.5135 Acc: 0.7490
# Time elapsed 3m 54s
# valid Loss: 0.4757 Acc: 0.7601
# Optimizer learning rate : 0.0000100
#
# Epoch 15/55
# ----------
# Time elapsed 4m 8s
# train Loss: 0.5250 Acc: 0.7361
# Time elapsed 4m 9s
# valid Loss: 0.4655 Acc: 0.7677
# Optimizer learning rate : 0.0000100
#
# Epoch 16/55
# ----------
# Time elapsed 4m 24s
# train Loss: 0.5090 Acc: 0.7504
# Time elapsed 4m 24s
# valid Loss: 0.4711 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 17/55
# ----------
# Time elapsed 4m 39s
# train Loss: 0.5193 Acc: 0.7466
# Time elapsed 4m 40s
# valid Loss: 0.4620 Acc: 0.7803
# Optimizer learning rate : 0.0000100
#
# Epoch 18/55
# ----------
# Time elapsed 4m 55s
# train Loss: 0.5194 Acc: 0.7387
# Time elapsed 4m 55s
# valid Loss: 0.4657 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 19/55
# ----------
# Time elapsed 5m 10s
# train Loss: 0.5003 Acc: 0.7534
# Time elapsed 5m 11s
# valid Loss: 0.4625 Acc: 0.7803
# Optimizer learning rate : 0.0000100
#
# Epoch 20/55
# ----------
# Time elapsed 5m 26s
# train Loss: 0.5294 Acc: 0.7291
# Time elapsed 5m 26s
# valid Loss: 0.4617 Acc: 0.7727
# Optimizer learning rate : 0.0000100
#
# Epoch 21/55
# ----------
# Time elapsed 5m 41s
# train Loss: 0.5200 Acc: 0.7303
# Time elapsed 5m 42s
# valid Loss: 0.4589 Acc: 0.7828
# Optimizer learning rate : 0.0000100
#
# Epoch 22/55
# ----------
# Time elapsed 5m 57s
# train Loss: 0.5295 Acc: 0.7297
# Time elapsed 5m 57s
# valid Loss: 0.4655 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 23/55
# ----------
# Time elapsed 6m 12s
# train Loss: 0.5170 Acc: 0.7387
# Time elapsed 6m 13s
# valid Loss: 0.4669 Acc: 0.7677
# Optimizer learning rate : 0.0000100
#
# Epoch 24/55
# ----------
# Time elapsed 6m 27s
# train Loss: 0.5126 Acc: 0.7440
# Time elapsed 6m 28s
# valid Loss: 0.4705 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 25/55
# ----------
# Time elapsed 6m 43s
# train Loss: 0.5141 Acc: 0.7414
# Time elapsed 6m 43s
# valid Loss: 0.4707 Acc: 0.7727
# Optimizer learning rate : 0.0000100
#
# Epoch 26/55
# ----------
# Time elapsed 6m 58s
# train Loss: 0.5069 Acc: 0.7390
# Time elapsed 6m 59s
# valid Loss: 0.4652 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 27/55
# ----------
# Time elapsed 7m 14s
# train Loss: 0.5110 Acc: 0.7461
# Time elapsed 7m 15s
# valid Loss: 0.4638 Acc: 0.7753
# Optimizer learning rate : 0.0000100
#
# Epoch 28/55
# ----------
# Time elapsed 7m 29s
# train Loss: 0.5158 Acc: 0.7373
# Time elapsed 7m 30s
# valid Loss: 0.4662 Acc: 0.7753
# Optimizer learning rate : 0.0000100
#
# Epoch 29/55
# ----------
# Time elapsed 7m 45s
# train Loss: 0.5122 Acc: 0.7420
# Time elapsed 7m 46s
# valid Loss: 0.4616 Acc: 0.7879
# Optimizer learning rate : 0.0000100
#
# Epoch 30/55
# ----------
# Time elapsed 8m 1s
# train Loss: 0.5094 Acc: 0.7428
# Time elapsed 8m 1s
# valid Loss: 0.4642 Acc: 0.7854
# Optimizer learning rate : 0.0000100
#
# Epoch 31/55
# ----------
# Time elapsed 8m 16s
# train Loss: 0.5132 Acc: 0.7364
# Time elapsed 8m 17s
# valid Loss: 0.4676 Acc: 0.7677
# Optimizer learning rate : 0.0000100
#
# Epoch 32/55
# ----------
# Time elapsed 8m 32s
# train Loss: 0.5080 Acc: 0.7466
# Time elapsed 8m 32s
# valid Loss: 0.4636 Acc: 0.7652
# Optimizer learning rate : 0.0000100
#
# Epoch 33/55
# ----------
# Time elapsed 8m 47s
# train Loss: 0.5017 Acc: 0.7531
# Time elapsed 8m 48s
# valid Loss: 0.4639 Acc: 0.7727
# Optimizer learning rate : 0.0000100
#
# Epoch 34/55
# ----------
# Time elapsed 9m 2s
# train Loss: 0.5167 Acc: 0.7472
# Time elapsed 9m 3s
# valid Loss: 0.4724 Acc: 0.7677
# Optimizer learning rate : 0.0000100
#
# Epoch 35/55
# ----------
# Time elapsed 9m 18s
# train Loss: 0.5030 Acc: 0.7501
# Time elapsed 9m 18s
# valid Loss: 0.4660 Acc: 0.7753
# Optimizer learning rate : 0.0000100
#
# Epoch 36/55
# ----------
# Time elapsed 9m 33s
# train Loss: 0.5095 Acc: 0.7396
# Time elapsed 9m 34s
# valid Loss: 0.4613 Acc: 0.7929
# Optimizer learning rate : 0.0000100
#
# Epoch 37/55
# ----------
# Time elapsed 9m 48s
# train Loss: 0.5084 Acc: 0.7414
# Time elapsed 9m 49s
# valid Loss: 0.4628 Acc: 0.7929
# Optimizer learning rate : 0.0000100
#
# Epoch 38/55
# ----------
# Time elapsed 10m 4s
# train Loss: 0.5186 Acc: 0.7352
# Time elapsed 10m 4s
# valid Loss: 0.4627 Acc: 0.7904
# Optimizer learning rate : 0.0000100
#
# Epoch 39/55
# ----------
# Time elapsed 10m 19s
# train Loss: 0.5062 Acc: 0.7481
# Time elapsed 10m 20s
# valid Loss: 0.4618 Acc: 0.7854
# Optimizer learning rate : 0.0000100
#
# Epoch 40/55
# ----------
# Time elapsed 10m 34s
# train Loss: 0.5153 Acc: 0.7385
# Time elapsed 10m 35s
# valid Loss: 0.4592 Acc: 0.7854
# Optimizer learning rate : 0.0000100
#
# Epoch 41/55
# ----------
# Time elapsed 10m 50s
# train Loss: 0.5115 Acc: 0.7376
# Time elapsed 10m 51s
# valid Loss: 0.4531 Acc: 0.7828
# Optimizer learning rate : 0.0000100
#
# Epoch 42/55
# ----------
# Time elapsed 11m 5s
# train Loss: 0.5188 Acc: 0.7358
# Time elapsed 11m 6s
# valid Loss: 0.4591 Acc: 0.7803
# Optimizer learning rate : 0.0000100
#
# Epoch 43/55
# ----------
# Time elapsed 11m 20s
# train Loss: 0.5173 Acc: 0.7463
# Time elapsed 11m 21s
# valid Loss: 0.4679 Acc: 0.7677
# Optimizer learning rate : 0.0000100
#
# Epoch 44/55
# ----------
# Time elapsed 11m 36s
# train Loss: 0.5176 Acc: 0.7393
# Time elapsed 11m 37s
# valid Loss: 0.4667 Acc: 0.7803
# Optimizer learning rate : 0.0000100
#
# Epoch 45/55
# ----------
# Time elapsed 11m 51s
# train Loss: 0.5148 Acc: 0.7423
# Time elapsed 11m 52s
# valid Loss: 0.4652 Acc: 0.7652
# Optimizer learning rate : 0.0000100
#
# Epoch 46/55
# ----------
# Time elapsed 12m 7s
# train Loss: 0.5140 Acc: 0.7446
# Time elapsed 12m 7s
# valid Loss: 0.4586 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 47/55
# ----------
# Time elapsed 12m 22s
# train Loss: 0.5004 Acc: 0.7572
# Time elapsed 12m 23s
# valid Loss: 0.4610 Acc: 0.7929
# Optimizer learning rate : 0.0000100
#
# Epoch 48/55
# ----------
# Time elapsed 12m 37s
# train Loss: 0.5224 Acc: 0.7352
# Time elapsed 12m 38s
# valid Loss: 0.4631 Acc: 0.7778
# Optimizer learning rate : 0.0000100
#
# Epoch 49/55
# ----------
# Time elapsed 12m 53s
# train Loss: 0.5059 Acc: 0.7519
# Time elapsed 12m 53s
# valid Loss: 0.4592 Acc: 0.7828
# Optimizer learning rate : 0.0000100
#
# Epoch 50/55
# ----------
# Time elapsed 13m 8s
# train Loss: 0.5032 Acc: 0.7519
# Time elapsed 13m 9s
# valid Loss: 0.4540 Acc: 0.7929
# Optimizer learning rate : 0.0000100
#
# Epoch 51/55
# ----------
# Time elapsed 13m 24s
# train Loss: 0.5078 Acc: 0.7461
# Time elapsed 13m 24s
# valid Loss: 0.4676 Acc: 0.7727
# Optimizer learning rate : 0.0000100
#
# Epoch 52/55
# ----------
# Time elapsed 13m 39s
# train Loss: 0.5087 Acc: 0.7493
# Time elapsed 13m 40s
# valid Loss: 0.4707 Acc: 0.7576
# Optimizer learning rate : 0.0000100
#
# Epoch 53/55
# ----------
# Time elapsed 13m 54s
# train Loss: 0.4990 Acc: 0.7516
# Time elapsed 13m 55s
# valid Loss: 0.4627 Acc: 0.7803
# Optimizer learning rate : 0.0000100
#
# Epoch 54/55
# ----------
# Time elapsed 14m 10s
# train Loss: 0.5001 Acc: 0.7469
# Time elapsed 14m 11s
# valid Loss: 0.4773 Acc: 0.7399
# Optimizer learning rate : 0.0000100
#
# Epoch 55/55
# ----------
# Time elapsed 14m 26s
# train Loss: 0.4984 Acc: 0.7531
# Time elapsed 14m 27s
# valid Loss: 0.4622 Acc: 0.7753
# Optimizer learning rate : 0.0000100
#
# Training complete in 14m 27 s
# Best val Acc:  0.792929

# %% [markdown]
# ### 3. 特征提取
# - 修改最优模型，把模型最后两层删掉
# - 模型进入验证模式，批量输入训练集和验证集构成一个集合

# %%
model_name = 'resnet'
feature_extract = True # 是否用人家训练好的特征来做
model_ft,_ = initialize_model(model_name, 2, feature_extract, use_pretrained=True)

#GPU计算
model_ft = model_ft.to(device)

# 直接加载模型
# model_ft = torch.load(filename)
checkpoint = torch.load('../modle_save/checkpoint_again2.pth')
best_acc = checkpoint['best_acc']
print(best_acc)
model_ft.load_state_dict(checkpoint['state_dict'])

# 修改model_tf为自己想要的
model_ft.fc = nn.Sequential(list(model_ft.children())[-1][0])

# 取得特征和对应的标签
def get_svmFeature(model_ft, dataloaders):
    model_ft.eval()

    feature = torch.Tensor([])
    ft_label = torch.Tensor([])
    for phase in ['train', 'valid']:
        for inputs, labels in dataloaders[phase] :
            inputs = inputs.to(device)

            output = model_ft(inputs)
            output = output.cpu().detach()
            feature = torch.cat((feature, output), 0)
            ft_label = torch.cat((ft_label, labels), 0)

    # 张量转化为numpy
    feature = feature.cpu().detach().numpy()
    ft_label = ft_label.cpu().numpy()
    
    return feature, ft_label


feature, ft_label = get_svmFeature(model_ft, dataloaders)
print(feature.shape)
print(ft_label.shape)

np.save('../face_data/sex_npy/img_feature.npy', feature)
np.save('../face_data/sex_npy/img_label.npy', ft_label)
# Out:
# tensor(0.7348, device='cuda:0', dtype=torch.float64)
# (3818, 100)
# (3818,)

# %% [markdown]
# ### 4. SVM交叉验证结果

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
import numpy as np

CNN_img_data = np.load('../face_data/sex_npy/img_feature_100.npy')  #读取图像文件
sex_label_list = np.load('../face_data/sex_npy/img_label_100.npy')  #读取标签文件

SVM = SVC(C=0.9, kernel='rbf', probability=True)

model = SVM
score = cross_val_score(model, CNN_img_data, sex_label_list, cv=5)
print(score.mean())
# Out:
# 0.7653221988156425
